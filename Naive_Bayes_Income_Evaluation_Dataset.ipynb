# %% [markdown]
# <a href="https://colab.research.google.com/github/RakeshKakati/DataScience-Project/blob/IncomeEvaluation/Naive_Bayes_Income_Evaluation_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
file = pd.read_csv('income_evaluation.csv')
file.head()
# Out:
#    Age          Workclass  Fnlwgt  ... Hours-per-week  Native-country  Income
# 0   39          State-gov   77516  ...             40   United-States   <=50K
# 1   50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2   38            Private  215646  ...             40   United-States   <=50K
# 3   53            Private  234721  ...             40   United-States   <=50K
# 4   28            Private  338409  ...             40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
# ...

# %%
sns.heatmap(file.corr())

# %%
sns.barplot(x='Workclass',y='Hours-per-week',data=file)

# %%
sns.pairplot(file)

# %%
sns.countplot(x='Income',data=file)

# %%
sns.barplot(x='Income',y='Age',data=file)

# %%
import numpy as np
cat_df = file.select_dtypes(object)
num_df = file.select_dtypes(np.number)

# %%
cat_df
# Out:
#                Workclass    Education  ...  Native-country  Income
# 0              State-gov    Bachelors  ...   United-States   <=50K
# 1       Self-emp-not-inc    Bachelors  ...   United-States   <=50K
# 2                Private      HS-grad  ...   United-States   <=50K
# 3                Private         11th  ...   United-States   <=50K
# 4                Private    Bachelors  ...            Cuba   <=50K
# ...                  ...          ...  ...             ...     ...
# 32556            Private   Assoc-acdm  ...   United-States   <=50K
# 32557            Private      HS-grad  ...   United-States    >50K
# 32558            Private      HS-grad  ...   United-States   <=50K
# 32559            Private      HS-grad  ...   United-States   <=50K
# 32560       Self-emp-inc      HS-grad  ...   United-States    >50K
#
# [32561 rows x 9 columns]

# %%
num_df
# Out:
#        Age  Fnlwgt  Education-num  Capital-gain  Capital-loss  Hours-per-week
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# [32561 rows x 6 columns]

# %%
new_cat_df = pd.get_dummies(cat_df,columns=cat_df.columns)
new_cat_df
# Out:
#        Workclass_ ?  Workclass_ Federal-gov  ...  Income_ <=50K  Income_ >50K
# 0                 0                       0  ...              1             0
# 1                 0                       0  ...              1             0
# 2                 0                       0  ...              1             0
# 3                 0                       0  ...              1             0
# 4                 0                       0  ...              1             0
# ...             ...                     ...  ...            ...           ...
# 32556             0                       0  ...              1             0
# 32557             0                       0  ...              0             1
# 32558             0                       0  ...              1             0
# 32559             0                       0  ...              1             0
# 32560             0                       0  ...              0             1
#
# [32561 rows x 104 columns]

# %%
new_cat_df.drop('Income_ >50K',axis=1,inplace=True)

# %%
new_cat_df
# Out:
#        Workclass_ ?  ...  Income_ <=50K
# 0                 0  ...              1
# 1                 0  ...              1
# 2                 0  ...              1
# 3                 0  ...              1
# 4                 0  ...              1
# ...             ...  ...            ...
# 32556             0  ...              1
# 32557             0  ...              0
# 32558             0  ...              1
# 32559             0  ...              1
# 32560             0  ...              0
#
# [32561 rows x 103 columns]

# %%
final_data = pd.concat([num_df,new_cat_df],axis=1)

# %%
final_data
# Out:
#        Age  Fnlwgt  ...  Native-country_ Yugoslavia  Income_ <=50K
# 0       39   77516  ...                           0              1
# 1       50   83311  ...                           0              1
# 2       38  215646  ...                           0              1
# 3       53  234721  ...                           0              1
# 4       28  338409  ...                           0              1
# ...    ...     ...  ...                         ...            ...
# 32556   27  257302  ...                           0              1
# 32557   40  154374  ...                           0              0
# 32558   58  151910  ...                           0              1
# 32559   22  201490  ...                           0              1
# 32560   52  287927  ...                           0              0
#
# [32561 rows x 109 columns]

# %%
X = final_data.drop('Income_ <=50K',axis=1)
y = final_data['Income_ <=50K']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,random_state=0,test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB,BernoulliNB

# %%
gau_nb = GaussianNB()
gau_nb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
ben_nb = BernoulliNB()
ben_nb.fit(X_train,y_train)
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
from sklearn.metrics import accuracy_score

# %%
pred = gau_nb.predict(X_test)
gau_acc = accuracy_score(y_test,pred)
gau_acc
# Out:
# 0.7974204115057836

# %%
pred = ben_nb.predict(X_test)
ben_acc = accuracy_score(y_test,pred)
ben_acc
# Out:
# 0.7602620534343331

# %%
plt.barh(['Gaussian','Bernoulli'],[gau_acc,ben_acc])
# Out:
# <BarContainer object of 2 artists>

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred = lr.predict(X_test)
lr_acc = accuracy_score(y_test,pred)
lr_acc
# Out:
# 0.7975227761285699

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[ 783 1579]
#  [ 399 7008]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.33      0.44      2362
#            1       0.82      0.95      0.88      7407
#
#     accuracy                           0.80      9769
#    macro avg       0.74      0.64      0.66      9769
# weighted avg       0.78      0.80      0.77      9769

# %%
plt.barh(['Gaussian','Bernoulli','Logistic Regression'],[gau_acc,ben_acc,lr_acc])
# Out:
# <BarContainer object of 3 artists>

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred = model.predict(X_test)
SVC_acc = accuracy_score(y_test,pred)
SVC_acc
# Out:
# 0.7920974511208926

# %%
plt.barh(['Gaussian','Bernoulli','Logistic Regression','SVM'],[gau_acc,ben_acc,lr_acc,SVC_acc])
# Out:
# <BarContainer object of 4 artists>
